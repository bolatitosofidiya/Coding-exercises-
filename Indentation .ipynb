# %%
# function
# if else
# for while
# class

# %%
# if(x>1):
#     statements
#     else:
#         for i in range(0,5):

# %%
x=1
if(x>=1):
    print("Correct")
# Out:
# Correct

# %%
for i in range(0,5):
    if (i > 3):
        print(i)
# Out:
# 4
