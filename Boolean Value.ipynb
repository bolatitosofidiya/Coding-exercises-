# %%
10
# Out:
# 10

# %%
bool(10)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(0.23)
# Out:
# True

# %%
bool(-23)
# Out:
# True

# %%
True|True
# Out:
# True

# %%
True|False
# Out:
# True

# %%
True*False
# Out:
# 0

# %%
False*False
# Out:
# 0

# %%
True*True
# Out:
# 1

# %% [markdown]
# #### And

# %%
True & True
# Out:
# True

# %%
False & True
# Out:
# False

# %%
False & False
# Out:
# False

# %%
# Or

# %%
True | True
# Out:
# True

# %%
True | False
# Out:
# True

# %%
False | False
# Out:
# False

# %%
x =10

# %%
x>7
# Out:
# True

# %%
x < 5
# Out:
# False

# %%
(x > 5) & (x < 9)
# Out:
# False

# %%
(x > 5) | (x < 9)
# Out:
# True

# %%
(x > 10) & (x < 16)
# Out:
# False

# %%
(x > 10) | (x < 16)
# Out:
# True
