# %%
a='Hello'

# %%
a
# Out:
# 'Hello'

# %%
b="Hello"

# %%
b
# Out:
# 'Hello'

# %%
c='''Hello'''

# %%
c
# Out:
# 'Hello'

# %%
c="""Hello"""

# %%
c
# Out:
# 'Hello'

# %%
d='Hello this is my first string program'

# %%
d
# Out:
# 'Hello this is my first string program'

# %% [markdown]
# # Indexing with string

# %%
d
# Out:
# 'Hello this is my first string program'

# %%
d[0]
# Out:
# 'H'

# %%
d[-1]
# Out:
# 'm'

# %%
d[7]
# Out:
# 'h'

# %%
d[5]
# Out:
# ' '

# %%
d[-5]
# Out:
# 'o'

# %%
d[-6]
# Out:
# 'r'

# %%
d
# Out:
# 'Hello this is my first string program'

# %%
d[:]
# Out:
# 'Hello this is my first string program'

# %%
d[0:]
# Out:
# 'Hello this is my first string program'

# %%
d[1:]
# Out:
# 'ello this is my first string program'

# %%
d[0:5]
# Out:
# 'Hello'

# %%
d[0: :2]
# Out:
# 'Hloti sm is tigporm'

# %%
d[::-1]
# Out:
# 'margorp gnirts tsrif ym si siht olleH'

# %%
d[6:]
# Out:
# 'this is my first string program'

# %%
d[0:10]
# Out:
# 'Hello this'

# %%
d[0:10:2]
# Out:
# 'Hloti'

# %%
d[0:10:3]
# Out:
# 'Hlts'

# %%
d[-1::-1]
# Out:
# 'margorp gnirts tsrif ym si siht olleH'

# %%
A=('  Hello World  ')

# %%
A
# Out:
# '  Hello World  '

# %%
A.strip()
# Out:
# 'Hello World'

# %%
A.upper()
# Out:
# '  HELLO WORLD  '

# %%
A= ('    Hello Angela    ')

# %%
A
# Out:
# '    Hello Angela    '

# %%
A.strip()
# Out:
# 'Hello Angela'

# %%
A.upper()
# Out:
# '    HELLO ANGELA    '

# %%
B=('   Hello    Bala  ')

# %%
B
# Out:
# '   Hello    Bala  '

# %%
B.strip()
# Out:
# 'Hello    Bala'

# %%
A=[10,20,40,40,87,56,90,43,22,21,6,34]

# %%
A.append([86,76,90])

# %%
A
# Out:
# [10, 20, 40, 40, 87, 56, 90, 43, 22, 21, 6, 34, [86, 76, 90]]

# %%
B=[56,76,84,89,34]

# %%
A.extend(B)

# %%
A
# Out:
# [10, 20, 40, 40, 87, 56, 90, 43, 22, 21, 6, 34]

# %%
len(A)
# Out:
# 12

# %%
A[-1]
# Out:
# 34

# %%
A.pop()
# Out:
# 34

# %%
A
# Out:
# [10, 20, 40, 40, 87, 56, 90, 43, 22, 21, 6]

# %%
A.remove(40)

# %%
A
# Out:
# [10, 20, 40, 87, 56, 90, 43, 22, 21, 6]

# %%
A[::-1]
# Out:
# [6, 21, 22, 43, 90, 56, 87, 40, 20, 10]

# %%
A.sort()

# %%
A
# Out:
# [6, 10, 20, 21, 22, 40, 43, 56, 87, 90]

# %%
A.sort(reverse=True)

# %%
A
# Out:
# [90, 87, 56, 43, 40, 22, 21, 20, 10, 6]

# %%
A
# Out:
# [90, 87, 56, 43, 40, 22, 21, 20, 10, 6]

# %%
A[::-1]
# Out:
# [6, 10, 20, 21, 22, 40, 43, 56, 87, 90]

# %%
A[0:6:2]
# Out:
# [90, 56, 40]

# %%
A
# Out:
# [90, 87, 56, 43, 40, 22, 21, 20, 10, 6]

# %%
A.count(22)
# Out:
# 1

# %%
d
# Out:
# 'Hello this is my first string program'

# %%
d[:2]
# Out:
# 'He'

# %%
d[:-2]
# Out:
# 'Hello this is my first string progr'

# %%
d[:10]
# Out:
# 'Hello this'

# %%
d[:6]
# Out:
# 'Hello '

# %%
d[6:]
# Out:
# 'this is my first string program'

# %%
d[0:10:2]
# Out:
# 'Hloti'

# %%
a ="       Hello Sala    "
b= 'I Love Football......'
c= 'Berlin,Nigeria,Libya,Ethiopia,South African,Sudan,London'

# %%
a
# Out:
# '       Hello Sala    '

# %%
b
# Out:
# 'I Love Football......'

# %%
c
# Out:
# 'Berlin,Nigeria,Libya,Ethiopia,South African,Sudan,London'

# %%
b.replace('Love','Hate')
# Out:
# 'I Hate Football......'

# %%
b.lower()
# Out:
# 'i love football......'

# %%
b.upper()
# Out:
# 'I LOVE FOOTBALL......'

# %%
a.strip()
# Out:
# 'Hello Sala'

# %%
c.lower()
# Out:
# 'berlin,nigeria,libya,ethiopia,south african,sudan,london'

# %%
len(b)
# Out:
# 21

# %%
b.count
# Out:
# <function str.count>

# %%
a.replace('Hello','Hey')
# Out:
# '       Hey Sala    '

# %%
a
# Out:
# '       Hello Sala    '

# %%
a = a.replace('Hello','Hey')

# %%
a
# Out:
# '       Hey Sala    '

# %%
b
# Out:
# 'I Love Football......'

# %%
b=b.replace('Love','hate')

# %%
b
# Out:
# 'I hate Football......'

# %%
b.replace('a','e')
# Out:
# 'I hete Footbell......'

# %%
a
# Out:
# '       Hey Sala    '

# %%
a.split(" ")
# Out:
# ['', '', '', '', '', '', '', 'Hey', 'Sala', '', '', '', '']

# %%
b.split(" ")
# Out:
# ['I', 'hate', 'Football......']

# %%
c.split(' ')
# Out:
# ['Berlin,Nigeria,Libya,Ethiopia,South', 'African,Sudan,London']

# %%
c.split()
# Out:
# ['Berlin,Nigeria,Libya,Ethiopia,South', 'African,Sudan,London']

# %%
c.split(',')
# Out:
# ['Berlin', 'Nigeria', 'Libya', 'Ethiopia', 'South African', 'Sudan', 'London']

# %%
'N' in B
# Out:
# False

# %%
'B' in A
# Out:
# False

# %%
'E' in c
# Out:
# True

# %%
"i" in c
# Out:
# True

# %%
'd' in c
# Out:
# True

# %%
'Z' not in c
# Out:
# True

# %%
'Nigeria' in c
# Out:
# True

# %%
'Sok' in c
# Out:
# False

# %%
"Sok" not in c
# Out:
# True

# %%
x = "He is a"legend" in football"
# Out:
#   Cell In[94], line 1
#     x = "He is a"legend" in football"
#                  ^
# SyntaxError: invalid syntax

# %%
x = "He is a \"lengend\" in football "

# %%
x
# Out:
# 'He is a "lengend" in football '

# %% [markdown]
# # \t

# %%
s='Hello\tWorld'

# %%
s
# Out:
# 'Hello\tWorld'

# %%
print(s)
# Out:
# Hello	World

# %% [markdown]
# # \n

# %%
f = 'Hello\nWorld'

# %%
f
# Out:
# 'Hello\nWorld'

# %%
print(f)
# Out:
# Hello
# World
