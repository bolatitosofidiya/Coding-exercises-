# %%
b=[1,2,[3,'a'],[4,'b']]

# %%
b[3][1]
# Out:
# 'b'

# %%
b=[1,2,3,4,5,6,67,8,9,10,11]

# %%
c=[5,6,6,8,9,8,3,2,1,11,1,10,2]

# %%
c=set(c)

# %%
c
# Out:
# {1, 2, 3, 5, 6, 8, 9, 10, 11}

# %%
c.add(15)

# %%
c
# Out:
# {1, 2, 3, 5, 6, 8, 9, 10, 11, 15}

# %%
c.remove(6)

# %%
c
# Out:
# {1, 2, 3, 5, 8, 9, 10, 11, 15}

# %%
6 in c
# Out:
# False

# %%
1 in c
# Out:
# True
