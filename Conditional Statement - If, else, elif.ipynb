# %%
temp = 30
if temp < 25:
    print("It's Hot")
    
elif temp > 50:
    print("It's Cold")
    
else:
    print("It's Warm")
# Out:
# It's Warm

# %% [markdown]
# ### How python evaluate multiple condition
# #### Rule 1
# #### Evaluate from top to bottom
# #### Rule `2
# #### Stop immediately after the first true condition
# #### Rule 3
# #### Ignore the remaimnimng elif statements
# #### Rule 4
# #### Execute else only if every previous condition

# %%
# The conditonal (Ternary) expression
# Python allows you to write the same logic in a one line expression

age = 22
note = "Eligible" if age >= 18 else "Not Eligible"
        
print(note)
# Out:
# Eligible
