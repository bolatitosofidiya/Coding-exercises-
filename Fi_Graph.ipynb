# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df = pd.read_csv("OrderData.csv")

# %%
df
# Out:
#        OrderID                    BrandName EmployeeCode  \
# 0      7651176  Blume Nigerian Limited PULL    BNLPL0032
# 1      7651176  Blume Nigerian Limited PULL    BNLPL0032
# 2      7651176  Blume Nigerian Limited PULL    BNLPL0032
# 3      7651157  Blume Nigerian Limited PULL    BNLPL0032
# 4      7651151  Blume Nigerian Limited PULL    BNLPL0032
# ...        ...                          ...          ...
# 98382  4036400  Blume Nigerian Limited PULL    BNLPL0036
# 98383  4035409  Blume Nigerian Limited PULL    BNLPL0036
# 98384  4013809  Blume Nigerian Limited PULL    BNLPL0036
# 98385  4013809  Blume Nigerian Limited PULL    BNLPL0036
# 98386  4013809  Blume Nigerian Limited PULL    BNLPL0036
#
#                          AgentName      MnagerName  Year Month  OrderDate  \
# 0      EKWOMADU CHINYERE JOSEPHINE   SALAMI ROTIMI  2023  June  6/22/2023
# 1      EKWOMADU CHINYERE JOSEPHINE   SALAMI ROTIMI  2023  June  6/22/2023
# ...

# %%
df.plot(x="Quantity", y="SKUName", kind="scatter",legend=True, title="Data Dump")
# Out:
# <Axes: title={'center': 'Data Dump'}, xlabel='Quantity', ylabel='SKUName'>
