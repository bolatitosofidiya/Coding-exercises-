# %%
x=10

# %%
type(x)
# Out:
# int

# %%
"Bisi"
# Out:
# 'Bisi'

# %%
type("Bisi")
# Out:
# str

# %%
x="10"

# %%
type(x)
# Out:
# str

# %%
x=10.24

# %%
type(x)
# Out:
# float

# %%
x=True

# %%
type(x)
# Out:
# bool

# %%
x=3+2j

# %%
type(x)
# Out:
# complex

# %%
x=[1,2,3,"Hello"]

# %%
type(x)
# Out:
# list

# %%
x={1,2,3,"Hello"}

# %%
type(x)
# Out:
# set

# %%
x=(1,2,3,"Hello")

# %%
type(x)
# Out:
# tuple

# %%
x={"Black":11,"Red":15,"Green":20}

# %%
type(x)
# Out:
# dict

# %% [markdown]
# # Type Casting

# %%
#  int -> float -> string

# %%
x="12"

# %%
type(x)
# Out:
# str

# %%
y=int(x)

# %%
type(y)
# Out:
# int

# %%
int("12")
# Out:
# 12

# %%
int(12.23)
# Out:
# 12

# %%
int(13.99)
# Out:
# 13

# %%
int(14.99)
# Out:
# 14

# %%
float("12")
# Out:
# 12.0

# %%
float(12.24)
# Out:
# 12.24

# %%
str("12")
# Out:
# '12'

# %%
str(12)
# Out:
# '12'

# %%
str(12.24)
# Out:
# '12.24'

# %%
float(12.24)
# Out:
# 12.24

# %%
type(int(float("12.23")))
# Out:
# int

# %%
int(12.23)
# Out:
# 12
