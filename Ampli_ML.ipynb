# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\U\Desktop\BolaPython\ML_data\OrderData.csv')
df.head()
# Out:
#    OrderID                    BrandName EmployeeCode  \
# 0  7651176  Blume Nigerian Limited PULL    BNLPL0032
# 1  7651176  Blume Nigerian Limited PULL    BNLPL0032
# 2  7651176  Blume Nigerian Limited PULL    BNLPL0032
# 3  7651157  Blume Nigerian Limited PULL    BNLPL0032
# 4  7651151  Blume Nigerian Limited PULL    BNLPL0032
#
#                      AgentName     MnagerName  Year Month  OrderDate  \
# 0  EKWOMADU CHINYERE JOSEPHINE  SALAMI ROTIMI  2023  June  6/22/2023
# 1  EKWOMADU CHINYERE JOSEPHINE  SALAMI ROTIMI  2023  June  6/22/2023
# 2  EKWOMADU CHINYERE JOSEPHINE  SALAMI ROTIMI  2023  June  6/22/2023
# 3  EKWOMADU CHINYERE JOSEPHINE  SALAMI ROTIMI  2023  June  6/22/2023
# 4  EKWOMADU CHINYERE JOSEPHINE  SALAMI ROTIMI  2023  June  6/22/2023
#
#   OrderTime DeliveryDate  ...       SalesType Statename CityName  \
# 0   4:05 PM    6/22/2023  ...  SecondarySales     Lagos      Ojo
# 1   4:05 PM    6/22/2023  ...  SecondarySales     Lagos      Ojo
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98387 entries, 0 to 98386
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   OrderID            98387 non-null  int64
#  1   BrandName          98387 non-null  object
#  2   EmployeeCode       98387 non-null  object
#  3   AgentName          98387 non-null  object
#  4   MnagerName         98372 non-null  object
#  5   Year               98387 non-null  int64
#  6   Month              98387 non-null  object
#  7   OrderDate          98387 non-null  object
#  8   OrderTime          98387 non-null  object
#  9   DeliveryDate       94727 non-null  object
#  10  DeliveryTime       94727 non-null  object
#  11  RecoDate           94730 non-null  object
#  12  RecoTime           94730 non-null  object
#  13  OrderSyncdate      97591 non-null  object
#  14  OrderSyncTime      97591 non-null  object
#  15  Quantity           98387 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# OrderID                 0
# BrandName               0
# EmployeeCode            0
# AgentName               0
# MnagerName             15
# Year                    0
# Month                   0
# OrderDate               0
# OrderTime               0
# DeliveryDate         3660
# DeliveryTime         3660
# RecoDate             3657
# RecoTime             3657
# OrderSyncdate         796
# OrderSyncTime         796
# Quantity                0
# Sales                   0
# Value                   0
# OrderLatitude           0
# OrderLongitude          0
# OrderAddress         3823
# CustomerCode            0
# CustomerName            0
# ContactNumber           0
# CustomerStatus          0
# CustomerType            0
# SalesType               0
# Statename             290
# CityName             3627
# CustomerLatitude       31
# CustomerLongitude      31
# OriginalAddress       162
# DistributorCode      2468
# DistributorName      2468
# SKUName                 0
# ...

# %%
df.describe()
# Out:
#             OrderID          Year     Quantity         Sales         Value  \
# count  9.838700e+04  98387.000000  98387.00000  98387.000000  9.838700e+04
# mean   6.233794e+06   2022.588218      5.38561  20058.894793  3.719108e+04
# std    9.058115e+05      0.492159     28.77518  11497.545568  1.764077e+05
# min    4.013809e+06   2022.000000      1.00000    100.000000  1.000000e+00
# 25%    5.491842e+06   2022.000000      1.00000  10159.000000  9.500000e+03
# 50%    6.333118e+06   2023.000000      2.00000  20068.000000  1.475000e+04
# 75%    7.045344e+06   2023.000000      5.00000  29998.500000  3.100000e+04
# max    7.651176e+06   2023.000000   2200.00000  40000.000000  1.364000e+07
#
#        OrderLatitude  OrderLongitude  ContactNumber  CustomerLatitude  \
# count   98387.000000    98387.000000   9.838700e+04      98356.000000
# mean        6.558814        3.363783   8.029752e+09          6.558649
# std         0.197283        0.343485   5.930447e+08          0.197338
# ...

# %%
df.loc[df['Statename'].isnull(), 'Statename'] = 'Lagos'

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# OrderID              0
# BrandName            0
# EmployeeCode         0
# AgentName            0
# MnagerName           0
# Year                 0
# Month                0
# OrderDate            0
# OrderTime            0
# DeliveryDate         0
# DeliveryTime         0
# RecoDate             0
# RecoTime             0
# OrderSyncdate        0
# OrderSyncTime        0
# Quantity             0
# Sales                0
# Value                0
# OrderLatitude        0
# OrderLongitude       0
# OrderAddress         0
# CustomerCode         0
# CustomerName         0
# ContactNumber        0
# CustomerStatus       0
# CustomerType         0
# SalesType            0
# Statename            0
# CityName             0
# CustomerLatitude     0
# CustomerLongitude    0
# OriginalAddress      0
# DistributorCode      0
# DistributorName      0
# SKUName              0
# SKUcode              0
# dtype: int64

# %%
df.sample(10)
# Out:
#        OrderID                    BrandName EmployeeCode  \
# 22365  7089528  Blume Nigerian Limited PULL    BNLPL0034
# 44015  6477494  Blume Nigerian Limited PULL    Bnlpl0028
# 58755  5983565  Blume Nigerian Limited PULL    bnlpl0040
# 94420  4634197  Blume Nigerian Limited PULL    BNLPL0001
# 6548   7455703  Blume Nigerian Limited PULL    BNLPL0043
# 69976  5625919  Blume Nigerian Limited PULL    BNLPL0018
# 44832  6457365  Blume Nigerian Limited PULL    BNLPL0032
# 72776  5528962  Blume Nigerian Limited PULL    BNLPL0016
# 60144  5948984  Blume Nigerian Limited PULL    BNLPL0009
# 72539  5539539  Blume Nigerian Limited PULL    bnlpl0040
#
#                           AgentName              MnagerName  Year     Month  \
# 22365            EZE CHIOMA MAUREEN         Emmanuel Tobore  2023     April
# 44015          OPARA NNEKA JENNIFER           SALAMI ROTIMI  2023  February
# 58755           BABA TUNDE BLESSING           SALAMI ROTIMI  2022  December
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# Load the data
df = pd.read_csv(r'C:/Users/U/Desktop/BolaPython/ML_data/OrderData.csv')

# Let's say 'date' and 'sales' are the columns
df['OrderDate'] = pd.to_datetime(df['OrderDate'])
df.set_index('OrderDate', inplace=True)

# Feature Engineering (adding a simple day feature for illustration)
df['OrderDate'] = df.index.day

# Splitting data
train = df[:-30]  # excluding last 30 days for testing
test = df[-30:]   # last 30 days for testing

X_train = train.drop('Sales', axis=1)
y_train = train['Sales']

X_test = test.drop('Sales', axis=1)
y_test = test['Sales']

# Training a simple linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predictions
predictions = model.predict(X_test)

# Evaluation
mae = mean_absolute_error(y_test, predictions)
print(f'Mean Absolute Error: {mae}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 28
#      26 # Training a simple linear regression model
#      27 model = LinearRegression()
# ---> 28 model.fit(X_train, y_train)
#      30 # Predictions
#      31 predictions = model.predict(X_test)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
# ...

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (98357, 35)
# (98357,)

# %%
print(X_train.dtypes)
print(y_train.dtypes)
# Out:
# OrderID                int64
# BrandName             object
# EmployeeCode          object
# AgentName             object
# MnagerName            object
# Year                   int64
# Month                 object
# OrderTime             object
# DeliveryDate          object
# DeliveryTime          object
# RecoDate              object
# RecoTime              object
# OrderSyncdate         object
# OrderSyncTime         object
# Quantity               int64
# Value                  int64
# OrderLatitude        float64
# OrderLongitude       float64
# OrderAddress          object
# CustomerCode          object
# CustomerName          object
# ContactNumber          int64
# CustomerStatus        object
# CustomerType          object
# SalesType             object
# Statename             object
# CityName              object
# CustomerLatitude     float64
# CustomerLongitude    float64
# OriginalAddress       object
# DistributorCode       object
# DistributorName       object
# ...

# %%
print(X_train.isnull().sum())
print(y_train.isnull().sum())
# Out:
# OrderID                 0
# BrandName               0
# EmployeeCode            0
# AgentName               0
# MnagerName             15
# Year                    0
# Month                   0
# OrderTime               0
# DeliveryDate         3643
# DeliveryTime         3643
# RecoDate             3640
# RecoTime             3640
# OrderSyncdate         795
# OrderSyncTime         795
# Quantity                0
# Value                   0
# OrderLatitude           0
# OrderLongitude          0
# OrderAddress         3820
# CustomerCode            0
# CustomerName            0
# ContactNumber           0
# CustomerStatus          0
# CustomerType            0
# SalesType               0
# Statename             290
# CityName             3624
# CustomerLatitude       27
# CustomerLongitude      27
# OriginalAddress       162
# DistributorCode      2462
# DistributorName      2462
# SKUName                 0
# SKUcode                 0
# OrderDate               0
# dtype: int64
# 0
