# %%
l1 = [3,5,20,22,11,6,45]

# %%
l1
# Out:
# [3, 5, 20, 22, 11, 6, 45]

# %%
l2 =[3,8,10,True,"Sam"]

# %%
l2
# Out:
# [3, 8, 10, True, 'Sam']

# %%
l3 = [10,30,20,40,50,80]

# %%
l3
# Out:
# [10, 30, 20, 40, 50, 80]

# %%
l3[0]
# Out:
# 10

# %%
l3[4]
# Out:
# 50

# %%
l1[-1]
# Out:
# 45

# %%
l2[-1]
# Out:
# 'Sam'

# %%
l3[-1]
# Out:
# 80

# %%
len(l3)
# Out:
# 6

# %%
# l3[first:last]

# %%
l3
# Out:
# [10, 30, 20, 40, 50, 80]

# %%
l3[0:3]
# Out:
# [10, 30, 20]

# %%
l3[0:5]
# Out:
# [10, 30, 20, 40, 50]

# %%
l3[:]
# Out:
# [10, 30, 20, 40, 50, 80]

# %%
l3[1:]
# Out:
# [30, 20, 40, 50, 80]

# %%
l3[:4]
# Out:
# [10, 30, 20, 40]

# %%
l3[1:-1]
# Out:
# [30, 20, 40, 50]

# %%
l3
# Out:
# [10, 30, 20, 40, 50, 80]

# %%
l3[0: :]
# Out:
# [10, 30, 20, 40, 50, 80]

# %%
l3[1 : : 2]
# Out:
# [30, 40, 80]

# %%
l3[1 : : 3]
# Out:
# [30, 50]

# %%
l3[ : : ]
# Out:
# [10, 30, 20, 40, 50, 80]

# %%
l3[1: 4 : -1]
# Out:
# []

# %%
l3[-1:1:-1]
# Out:
# [80, 50, 40, 20]

# %%
l3[::1]
# Out:
# [10, 30, 20, 40, 50, 80]

# %%
l3[::2]
# Out:
# [10, 20, 50]

# %%
l3[::3]
# Out:
# [10, 40]

# %%
l3[::-1]
# Out:
# [80, 50, 40, 20, 30, 10]

# %%
l3[::-2]
# Out:
# [80, 40, 30]

# %%
l3[::-3]
# Out:
# [80, 20]
