# %% [markdown]
# # Addition

# %%
10+2+5+7
# Out:
# 24

# %%
23+65+3+3
# Out:
# 94

# %% [markdown]
# # Subtraction

# %%
10-4
# Out:
# 6

# %%
34-5
# Out:
# 29

# %%
76-87
# Out:
# -11

# %%
34-12
# Out:
# 22

# %% [markdown]
# # Multiplication

# %%
10*2
# Out:
# 20

# %%
34*3
# Out:
# 102

# %%
100*1
# Out:
# 100

# %%
20*3
# Out:
# 60

# %% [markdown]
# # Division

# %%
100/2
# Out:
# 50.0

# %%
86/6
# Out:
# 14.333333333333334

# %%
94/3
# Out:
# 31.333333333333332

# %%
560/4
# Out:
# 140.0

# %% [markdown]
# # Exponentiation

# %%
2**5
# Out:
# 32

# %%
3**6
# Out:
# 729

# %%
4**3
# Out:
# 64

# %%
5**3
# Out:
# 125

# %%
8**3
# Out:
# 512

# %%
pow(2,5)
# Out:
# 32

# %%
pow(4,3)
# Out:
# 64

# %%
pow(5,3)
# Out:
# 125

# %%
pow(8,3)
# Out:
# 512

# %% [markdown]
# # Quotient

# %%
100//11
# Out:
# 9

# %%
58//3
# Out:
# 19

# %%
78//11
# Out:
# 7

# %%
99//5
# Out:
# 19

# %%
67//3
# Out:
# 22

# %% [markdown]
# # Modulus
# ### This returns the remainder after one number is divided by another

# %%
10%3
# Out:
# 1

# %%
68%5
# Out:
# 3

# %%
57%7
# Out:
# 1

# %%
98%3
# Out:
# 2

# %%
79/2
# Out:
# 39.5

# %%
79//2
# Out:
# 39

# %%
79%2
# Out:
# 1

# %%
79/2
# Out:
# 39.5

# %% [markdown]
# #Q * No with which you are dividing + addition of remaining

# %%
68/7
# Out:
# 9.714285714285714

# %%
68//7
# Out:
# 9

# %%
68%7
# Out:
# 5

# %%
7*9+5
# Out:
# 68

# %%
2*39+1
# Out:
# 79

# %%
57/2
# Out:
# 28.5

# %%
57//2
# Out:
# 28

# %%
57%2
# Out:
# 1

# %%
2*28+1
# Out:
# 57

# %%
print("Hello")
print("Girl")
# Out:
# Hello
# Girl

# %%
x=10
while (x>1):
    print (x)
    x-=1
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
number = 11
print(number%2)
# Out:
# 1

# %%
if number %2 ==0:
    print("Even")
