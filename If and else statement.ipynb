# %%
x =15

# %%
if (x > 7):
    print("x is greater than 5")
# Out:
# x is greater than 5

# %%
if (x > 15):
    print("x is greater than 15")

# %%
if(x >= 15):
    print("x is greater than 15")
else: 
    print("x is lesser than 15")
# Out:
# x is greater than 15

# %%
if (x <= 5):
    print("x is lesser than eqaul to 5")
elif (x > 5) and (x < 10):
    print("x is between 5 and 10")
else:
    print("x is greater than equal to 10")
# Out:
# x is greater than equal to 10

# %%
if(x<=5):
    print("x is lesser than equal to 5")
elif(x > 5) & (x < 15):
    print("x is between 5 and 15")
else:
    print("x is greater than equal to 15")
# Out:
# x is greater than equal to 15

# %%
# if no. is divided by 2 then it is even
# If no. is divided by 2 or 5 or 7, it can be divided
# If no. is not divided by 2 or 5 or 7 then it can not be divided

# %%
if(x % 2==0):
    print("x is even")
elif(x % 5==0) | (x % 7==0):
    print("x can be divided")
else:
    print("x can not be divided")
# Out:
# x can not be divided

# %%
x = 1.05
