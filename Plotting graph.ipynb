# %%
import pandas as pd

# %%
df = pd.read_csv('OrderData.csv')

# %%
df.columns
# Out:
# Index(['OrderID', 'BrandName', 'EmployeeCode', 'AgentName', 'MnagerName',
#        'Year', 'Month', 'OrderDate', 'OrderTime', 'DeliveryDate',
#        'DeliveryTime', 'RecoDate', 'RecoTime', 'OrderSyncdate',
#        'OrderSyncTime', 'Quantity', 'Unit', 'Value', 'OrderLatitude',
#        'OrderLongitude', 'OrderAddress', 'CustomerCode', 'CustomerName',
#        'ContactNumber', 'CustomerStatus', 'CustomerType', 'SalesType',
#        'Statename', 'CityName', 'CustomerLatitude', 'CustomerLongitude',
#        'OriginalAddress', 'DistributorCode', 'DistributorName', 'SKUName',
#        'SKUcode'],
#       dtype='object')

# %%
df.plot()
# Out:
# <Axes: >

# %%
df['Quantity'].plot()
# Out:
# <Axes: >

# %%
df['Quantity'].plot(legend=True)
# Out:
# <Axes: >

# %%
df.plot(x='Quantity',y='SKUName',kind='scatter',legend=True)
# Out:
# <Axes: xlabel='Quantity', ylabel='SKUName'>

# %%
df.plot(title='Sample Plot',figsize=(15,10))
# Out:
# <Axes: title={'center': 'Sample Plot'}>

# %%
df['Quantity'].plot(kind='box',title ='Damn')
# Out:
# <Axes: title={'center': 'Damn'}>

# %%
df.plot(x ='Quantity',y ='SKUName', kind = 'scatter',title='Damn', legend='True')
# Out:
# <Axes: title={'center': 'Damn'}, xlabel='Quantity', ylabel='SKUName'>

# %%
df['Quantity'].plot(kind='hist',title ='Damn')
# Out:
# <Axes: title={'center': 'Damn'}, ylabel='Frequency'>

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import style

# %%
# %matplotlib inline

# %%
ran = 'dance','skip','run','jump','judo','karate'
no =[30,7,10,23,17,13]

# %%
 plt.figure(figsize=(10,10))

# %%
explode =(0.05,0,0,0,0,0)

# %%
plt.pie(no, labels =ran, explode=explode, autopct ='%1.1f%%', startangle =70)
# Out:
# ([<matplotlib.patches.Wedge at 0x201b1cbb790>,
# ...
#  [Text(-0.6430718746966038, 0.9533931843548052, 'dance'),
#   Text(-1.08122886871902, -0.2023465676718741, 'skip'),
#   Text(-0.8276563407661874, -0.7245584735475287, 'run'),
#   Text(0.20234659297986188, -1.0812288639827565, 'jump'),
#   Text(1.0908382953347697, -0.1416750275494386, 'judo'),
#   Text(0.755796175082626, 0.799232220152862, 'karate')],
#  [Text(-0.3634754074372108, 0.5388744085483681, '30.0%'),
#   Text(-0.5897612011194654, -0.11037085509374948, '7.0%'),
#   Text(-0.4514489131451931, -0.3952137128441065, '10.0%'),
#   Text(0.11037086889810646, -0.589761198536049, '23.0%'),
#   Text(0.5950027065462379, -0.07727728775423921, '17.0%'),
#   Text(0.41225245913597774, 0.4359448473561065, '13.0%')])
