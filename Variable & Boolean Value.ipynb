# %%
var=10

# %%
var
# Out:
# 10

# %%
var =25

# %%
var
# Out:
# 25

# %%
var=10

# %%
_var=20

# %%
Var=15

# %%
var
# Out:
# 10

# %%
Var
# Out:
# 15

# %%
_var
# Out:
# 20

# %% [markdown]
# # Arithmetic Operations

# %%
x=2
y=3

# %%
#multiplication 
x*y
# Out:
# 6

# %%
#Addition
x+y
# Out:
# 5

# %%
#Subraction
x-y
# Out:
# -1

# %%
#Division
x/y
# Out:
# 0.6666666666666666

# %%
#Exponent
x**y
# Out:
# 8

# %%
#Exponent or power
pow(x,y)
# Out:
# 8

# %%
#Quotient
x//y
# Out:
# 0

# %%
#Modulus
x%y
# Out:
# 2

# %% [markdown]
# # Boolean Value

# %%
10
# Out:
# 10

# %%
bool(10)
# Out:
# True

# %%
bool(12)
# Out:
# True

# %%
# Boolean will return true when condition is satisfing when it is not satisfactory it is false

# %%
# True=1
# False=0
