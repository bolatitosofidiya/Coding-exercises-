# %%
import pandas as pd

# %%
df = pd.read_csv('PandasExample.csv',parse_dates=True)

# %%
df.head()
# Out:
#   FlightID   Date  RouteID  Departure Delay  AircraftID  Scheduled Departure  \
# 0  Flight1  41972  ORD-BOS              3.9          43             0.750000
# 1  Flight2  41967  ORD-JFK              6.8          61             0.791667
# 2  Flight3  42238  ORD-EWR              2.7          72             0.708333
# 3  Flight4  41833  ORD-LAX              3.8         172             0.729167
# 4  Flight5  42135  ORD-IAH              3.0          89             0.708333
#
#    Avg Ticket Price  Total Fare  Flight Month  Flight Year
# 0             450.0     74250.0            11         2014
# 1             375.0     61875.0            11         2014
# 2             247.5     44797.5             8         2015
# 3             385.0     63525.0             7         2014
# 4             200.0     36200.0             5         2015

# %%
df.set_index(['Flight Month','FlightID'])
# Out:
#                           Date  RouteID  Departure Delay  AircraftID  \
# Flight Month FlightID
# 11           Flight1     41972  ORD-BOS              3.9          43
#              Flight2     41967  ORD-JFK              6.8          61
# 8            Flight3     42238  ORD-EWR              2.7          72
# 7            Flight4     41833  ORD-LAX              3.8         172
# 5            Flight5     42135  ORD-IAH              3.0          89
# ...                        ...      ...              ...         ...
#              Flight9632  42146  ORD-DEN              2.8          85
# 6            Flight9633  41818  ORD-DEN              1.6         185
# 12           Flight9634  42361  ORD-JFK              4.3         165
# 7            Flight9635  42188  ORD-MIA              2.8         201
# 5            Flight9636  42126  ORD-PHX              1.7         176
#
#                          Scheduled Departure  Avg Ticket Price  Total Fare  \
# Flight Month FlightID
# ...

# %%
df.set_index(['Flight Month','FlightID'],inplace=True)

# %%
df.index
# Out:
# MultiIndex([(11,    'Flight1'),
#             (11,    'Flight2'),
#             ( 8,    'Flight3'),
#             ( 7,    'Flight4'),
#             ( 5,    'Flight5'),
#             (12,    'Flight6'),
#             ( 3,    'Flight7'),
#             (11,    'Flight8'),
#             ( 5,    'Flight9'),
#             ( 9,   'Flight10'),
#             ...
#             ( 7, 'Flight9627'),
#             ( 8, 'Flight9628'),
#             ( 3, 'Flight9629'),
#             ( 2, 'Flight9630'),
#             (10, 'Flight9631'),
#             ( 5, 'Flight9632'),
#             ( 6, 'Flight9633'),
#             (12, 'Flight9634'),
#             ( 7, 'Flight9635'),
#             ( 5, 'Flight9636')],
#            names=['Flight Month', 'FlightID'], length=9636)

# %%
df.loc[6]
# Out:
#              Date  RouteID  Departure Delay  AircraftID  Scheduled Departure  \
# FlightID
# Flight29    41818  ORD-ATL              7.3         149             0.437500
# Flight51    42164  ORD-JFK              1.5           3             0.791667
# Flight74    41803  ORD-EWR              1.2          52             0.333333
# Flight82    41802  ORD-SEA              3.3          70             0.750000
# Flight88    41807  ORD-LAS              2.0         116             0.812500
# ...           ...      ...              ...         ...                  ...
# Flight9597  42180  ORD-PHX              2.5          10             0.625000
# Flight9604  42168  ORD-DFW              2.5          31             0.354167
# Flight9622  42170  ORD-MIA              3.0         122             0.708333
# Flight9626  41819  ORD-SFO              1.3          26             0.750000
# Flight9633  41818  ORD-DEN              1.6         185             0.291667
#
# ...

# %%
df.iloc[6]
# Out:
# Date                     41726
# RouteID                ORD-DEN
# Departure Delay            1.7
# AircraftID                 138
# Scheduled Departure      0.625
# Avg Ticket Price         300.0
# Total Fare             55500.0
# Flight Year               2014
# Name: (3, Flight7), dtype: object
