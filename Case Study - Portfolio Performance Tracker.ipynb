# %% [markdown]
# # INDUSTRY: FutureVest FinTech Ltd

# %% [markdown]
# ### An application for tracking portfolio performance and key investment indicators.

# %%
# First Investor Portfolio Information

investor_name01 = "Chinedu Okeke"
investment_name01 = "Tech Growth Fund"
initial_investment01 = 2500000
current_value01 = 2875000
additional_deposit01 = 150000
target_value01 = 3000000
annual_target_return01 = 0.15
current_return01 = 0.13
active_status01 = True

# %%
## Task 2 — Calculate Current Investment Profit 

profit01 = current_value01 - initial_investment01
print("Profit:", profit)
# Out:
# Profit: 375000

# %%
# Task 3 — Calculate Return on Investment (ROI)

roi01 = (profit01 / initial_investment01) * 100 
print("ROI:", roi01)
# Out:
# ROI: 15.0

# %%
## Task 4 — Update the Portfolio Value

current_value01 += additional_deposit01
print("Current Portfolio Value:",current_value01)
# Out:
# Current Portfolio Value: 3025000

# %%
## Task 5 — Check if the Investment Target Has Been Reached

current_value01 >= target_value01
print ("Target Achieved:", current_value01 >= target_value01)
# Out:
# Target Achieved: True

# %%
## Task 6 — Check if the Investment Performance Meets Expectations

current_return01 >= annual_target_return01
print("Performance Meets Expectation:", current_return01 >= annual_target_return01)
# Out:
# Performance Meets Expectation: False

# %%
## Task 7 — Determine Portfolio Health

active_status01 and current_value01 >= target_value01
print("Portfolio Healthy:", active_status01 and current_value01 >= target_value01)
# Out:
# Portfolio Healthy: True

# %%
## Task 8 — Determine if Financial Advisor Review Is Required

active_status01 and current_value01 >= target_value01 or current_return01 >= annual_target_return01
print("Financial Advisor Required:", active_status01 and current_value01 >= target_value01 or current_return01 >= annual_target_return01)
# Out:
# Financial Advisor Required: True

# %%
## Task 9 — Generate the Portfolio Performance Report

print("==========================================================")
print("            PORTFOLIO PERFORMANCE REPORT")
print("==========================================================")
print("Investor Name:", investor_name01)
print("Investment:", investment_name01)
print("Initial Investment:", initial_investment01)
print("Updated Portfolio Value", current_value01)
print("Current Profit:", profit01)
print("Return on Investment (ROI):", roi01)
print("Annual Target Return:", annual_target_return01)
print("Current Return:", current_return01)
print("Investment Target Achieved:", current_value01 >= target_value01)
print("Performance Meets Expectation", current_return01 >= annual_target_return01)
print("Portfolio Active:", active_status01)
print("Portfolio Healthy:", active_status01 and current_value01 >= target_value01)
print("Financial Advisor Review Required:", active_status01 and current_value01 >= target_value01 or current_return01 >= annual_target_return01)
# Out:
# ...
#             PORTFOLIO PERFORMANCE REPORT
# ...
# Investor Name: Chinedu Okeke
# Investment: Tech Growth Fund
# Initial Investment: 2500000
# Updated Portfolio Value 3025000
# Current Profit: 375000
# Return on Investment (ROI): 15.0
# Annual Target Return: 0.15
# Current Return: 0.13
# Investment Target Achieved: True
# Performance Meets Expectation False
# Portfolio Active: True
# Portfolio Healthy: True
# Financial Advisor Review Required: True

# %%
# Second Investor Portfolio Information

investor_name02 = "Amina Bello"
investment_name02 = "Renewable Energy Fund"
initial_investment02 = 1800000
current_value02 = 2160000
additional_deposit02 = 50000
target_value02 = 2200000
annual_target_return02 = 0.18
current_return02 = 20
active_status02 = True

# %%
## Task 10 — Calculate Current Investment Profit 

profit02 = current_value02 - initial_investment02
print("Profit:", profit02)
# Out:
# Profit: 360000

# %%
# Task 11 — Calculate Return on Investment (ROI)

roi02 = (profit02 / initial_investment02) * 100
print("ROI:", roi)
# Out:
# ROI: 20.0

# %%
## Task 12 — Update the Portfolio Value

current_value02 += additional_deposit02
print("Current Portfolio Value:", current_value02)
# Out:
# Current Portfolio Value: 2210000

# %%
## Task 13 — Check if the Investment Target Has Been Reached
print ("Target Achieved:", current_value02 >= target_value02)
# Out:
# Target Achieved: True

# %%
## Task 14 — Check if the Investment Performance Meets Expectations
print("Performance Meets Expectation:", current_return02 >= annual_target_return02)
# Out:
# Performance Meets Expectation: True

# %%
## Task 15 — Determine Portfolio Health

active_status02 and current_value02 >= target_value02
print("Portfolio Healthy:", active_status02 and current_value02 >= target_value02)
# Out:
# Portfolio Healthy: True

# %%
## Task 16 — Determine if Financial Advisor Review Is Required

active_status02 and current_value02 >= target_value02 or current_return02 >= annual_target_return02
print("Financial Advisor Required:", active_status02 and current_value02 >= target_value02 or current_return02 >= annual_target_return02)
# Out:
# Financial Advisor Required: True

# %%
## Task 17 — Generate the Portfolio Performance Report

print("==========================================================")
print("            PORTFOLIO PERFORMANCE REPORT")
print("==========================================================")
print("Investor Name:", investor_name02)
print("Investment:", investment_name02)
print("Initial Investment:", initial_investment02)
print("Updated Portfolio Value", current_value02)
print("Current Profit:", profit02)
print("Return on Investment (ROI):", roi02)
print("Annual Target Return:", annual_target_return02)
print("Current Return:", current_return02)
print("Investment Target Achieved:", current_value02 >= target_value02)
print("Performance Meets Expectation", current_return02 >= annual_target_return02)
print("Portfolio Active:", active_status02)
print("Portfolio Healthy:", active_status02 and current_value02 >= target_value02)
print("Financial Advisor Review Required:", active_status02 and current_value02 >= target_value02 or current_return02 >= annual_target_return02)
# Out:
# ...
#             PORTFOLIO PERFORMANCE REPORT
# ...
# Investor Name: Amina Bello
# Investment: Renewable Energy Fund
# Initial Investment: 1800000
# Updated Portfolio Value 2210000
# Current Profit: 360000
# Return on Investment (ROI): 20.0
# Annual Target Return: 0.18
# Current Return: 20
# Investment Target Achieved: True
# Performance Meets Expectation True
# Portfolio Active: True
# Portfolio Healthy: True
# Financial Advisor Review Required: True

# %% [markdown]
# ## Additional Questions.
#
# #### Question 1: Which investor has the higher ROI?
#
# #### Answer: The second investor Amina Bello has a higher ROI.

# %% [markdown]
# #### Question 2: Which investor generated more profit?
#
# #### Answer: The first investor Chinedu Okeke generated more profit.

# %% [markdown]
# #### Question 3: Which investor achieved their target portfolio value?
# #### Answer: Both investors achieved their target value.

# %% [markdown]
# #### Question 4: Which portfolio meets its annual return expectation?
# #### Answer: The second investor meet its annual return expectation.

# %% [markdown]
# #### Question 5: Which investor requires a financial advisor review?
# #### Answer: The first investor requires a financial advisor review.

# %% [markdown]
# #### Question 6: If you were the investment manager, which portfolio would you consider stronger based on your calculations?
# #### Answer: The second portfolio has a higher ROI and this is goal of investment.
