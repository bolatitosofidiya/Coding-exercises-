# %% [markdown]
# # Function
# ### This can be referred to as a resuable block of code that perform specific task e.g print()

# %% [markdown]
# # Argument
# ### This are pieces of information passed into a function e.g print("Argument")

# %% [markdown]
# # Variable
# ### This are container used to store information e.g name = "Luffy"....anytime l ask for name e.g print(name) i get Luffy
# ### can contain underscore, numbers and letter
# ### cant's contain space and cant use python keywords like if, for or class
# #### The variable here is name

# %%
name = "Luffy"
print(name)
# Out:
# Luffy

# %% [markdown]
# # The Assignment Operator
# ### = this symbol does not mean equal to, it means store data on right inside the variable on the left

# %%
salary = 150000
bonus = 15000
total = (salary + bonus)
print(total)
# Out:
# 165000

# %%
Movie_Name = "Krapopolis"
Title = len(Movie_Name)
print(Title)
# Out:
# 10

# %%
Movie_Name = "Krapopolis"
print(len(Movie_Name))
# Out:
# 10

# %% [markdown]
# ## There are 2 example above that return the number of text in a string but the difference between the two is;
#
# ### The first example stores the numbers of letters after the "=" sign in the varaible(container) called Title so whenever l need to know how many letters are the movie_name l just print(Title).
#
# ### The second example just shows me the number of letters in the string without storing it.

# %%
name = input("Enter your name")
age= input ("Enter your age")
print("Hello,", name , "Welcome to our store")
# Out:
# Enter your nameStella
# Enter your age30
# Hello, Stella Welcome to our store

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
print("Hello,", name, "Welcome to our store")
# Out:
# Enter your name: Queen
# Enter your age: 24
# Hello, Queen Welcome to our store

# %%
age = 25
print(type(age))
# Out:
# <class 'int'>

# %%
price = 20.55
print(type(price))
# Out:
# <class 'float'>

# %%
name = "Ayo"
print(type(name))
# Out:
# <class 'str'>

# %%
status = True
print(type(status))
# Out:
# <class 'bool'>
