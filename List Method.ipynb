# %%
A =[10,29,30,35,25,30,10,25,29,67,20,20,100,45,76,87]

# %%
A
# Out:
# [10, 29, 30, 35, 25, 30, 10, 25, 29, 67, 20, 20, 100, 45, 76, 87]

# %% [markdown]
# # Append

# %%
A.append(19)

# %%
A
# Out:
# [10, 29, 30, 35, 25, 30, 10, 25, 29, 67, 20, 20, 100, 45, 76, 87, 19]

# %%
A.append([10,20])

# %%
A
# Out:
# [10, 29, 30, 35, 25, 30, 10, 25, 29, 67, 20, 20, 100, 45, 76, 87, 19, [10, 20]]

# %% [markdown]
# #### Extend List

# %%
A.extend([10,20,30,56,98])

# %%
A
# Out:
# [10,
#  29,
#  30,
#  35,
#  25,
#  30,
#  10,
#  25,
#  29,
#  67,
#  20,
#  20,
#  100,
#  45,
#  76,
#  87,
#  19,
#  10,
#  20,
#  30,
#  56,
#  98]

# %%
B=[34,45,83,45]

# %%
A.extend(B)

# %%
A
# Out:
# [10,
#  29,
#  30,
#  35,
#  25,
#  30,
#  10,
#  25,
#  29,
#  67,
#  20,
#  20,
#  100,
#  45,
#  76,
#  87,
#  19,
#  10,
#  20,
#  30,
#  56,
#  98,
#  10,
#  20,
#  30,
#  56,
#  98,
#  34,
#  45,
#  83,
#  45]

# %% [markdown]
# # Insert

# %%
A =[10,29,30,35,25,30,10,25,29,67,20,20,100,45,76,87]

# %%
A[::-1]
# Out:
# [87, 76, 45, 100, 20, 20, 67, 29, 25, 10, 30, 25, 35, 30, 29, 10]

# %%
A
# Out:
# [10, 29, 30, 35, 25, 30, 10, 25, 29, 67, 20, 20, 100, 45, 76, 87]

# %%
A.insert(2,24)

# %%
A
# Out:
# [10, 29, 24, 30, 35, 25, 30, 10, 25, 29, 67, 20, 20, 100, 45, 76, 87]

# %% [markdown]
# # POP

# %%
A =[10,29,30,35,25,30,10,25,29,67,20,20,100,45,76,87]

# %%
A.pop()
# Out:
# 87

# %%
A
# Out:
# [10, 29, 24, 30, 35, 25, 30, 10, 25, 29, 67, 20, 20, 100, 45, 76]

# %%
A.pop(0)
# Out:
# 10

# %%
A.pop(-1)
# Out:
# 76

# %% [markdown]
# # Remove

# %%
A =[10,29,30,35,25,30,10,25,29,67,20,20,100,45,76,87]

# %%
A.remove(30)

# %%
A
# Out:
# [10, 29, 35, 25, 30, 10, 25, 29, 67, 20, 20, 100, 45, 76, 87]

# %%
A.remove(29)

# %%
A
# Out:
# [10, 35, 25, 30, 10, 25, 29, 67, 20, 20, 100, 45, 76, 87]

# %% [markdown]
# # Count

# %%
A =[10,29,30,35,25,30,10,25,29,67,20,20,100,45,76,87]

# %%
A.count(30)
# Out:
# 2

# %%
A.count(20)
# Out:
# 2

# %%
A.count(15)
# Out:
# 0

# %% [markdown]
# # Index

# %%
A
# Out:
# [10, 29, 30, 35, 25, 30, 10, 25, 29, 67, 20, 20, 100, 45, 76, 87]

# %%
A.index(30)
# Out:
# 2

# %%
A.index(29)
# Out:
# 1

# %% [markdown]
# # Reverse

# %%
A
# Out:
# [10, 29, 30, 35, 25, 30, 10, 25, 29, 67, 20, 20, 100, 45, 76, 87]

# %%
A.reverse()

# %%
A
# Out:
# [87, 76, 45, 100, 20, 20, 67, 29, 25, 10, 30, 25, 35, 30, 29, 10]

# %% [markdown]
# # Sort

# %%
A
# Out:
# [10, 29, 30, 35, 25, 30, 10, 25, 29, 67, 20, 20, 100, 45, 76, 87]

# %%
A.sort()

# %%
A
# Out:
# [10, 10, 20, 20, 25, 25, 29, 29, 30, 30, 35, 45, 67, 76, 87, 100]

# %%
A.sort(reverse = True)

# %%
A
# Out:
# [100, 87, 76, 67, 45, 35, 30, 30, 29, 29, 25, 25, 20, 20, 10, 10]

# %% [markdown]
# # Len

# %%
len(A)
# Out:
# 16

# %%
A.remove(10)

# %%
A.pop(-1)
# Out:
# 10

# %%
A
# Out:
# [100, 87, 76, 67, 45, 35, 30, 30, 29, 29, 25, 25, 20, 20]

# %%
len(A)
# Out:
# 14
