# %%
import pandas as pd

# %%
l = [x for x in range (5)]

# %%
s =pd.Series(l)

# %%
s
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
s[3]
# Out:
# 3

# %%
s = pd.Series(l,index=['a','b','c','d','e'])

# %%
s
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
s['c']
# Out:
# 2

# %%
s = pd.Series(l,index=['a','b','c','d','d'])

# %%
s['d']
# Out:
# d    3
# d    4
# dtype: int64

# %%
data = {'a': 1, 'b':2, 'c':3, 'd':4}

# %%
s=pd.Series(data)

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# #### When you need only selected data you can write like this

# %%
s = pd.Series(data,index=['a','b'])

# %%
s
# Out:
# a    1
# b    2
# dtype: int64

# %%
s = pd.Series(data,index=['a','b','c','f'])

# %%
s
# Out:
# a    1.0
# b    2.0
# c    3.0
# f    NaN
# dtype: float64

# %%
|
