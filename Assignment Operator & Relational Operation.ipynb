# %%
x=5

# %%
x
# Out:
# 5

# %%
x+=10

# %%
x
# Out:
# 15

# %%
x-=2

# %%
x
# Out:
# 13

# %%
x*=2

# %%
x
# Out:
# 26

# %%
x/=2

# %%
x
# Out:
# 3.25

# %%
x**=3

# %%
x
# Out:
# 34.328125

# %%
x%=2

# %%
x
# Out:
# 0.328125

# %%
x*10
# Out:
# 3.28125

# %%
x *=10

# %%
x
# Out:
# 3.28125

# %%
x=45

# %%
x//=2

# %%
x
# Out:
# 22

# %%
x//=2

# %%
x
# Out:
# 11

# %%
 10 > 7
# Out:
# True

# %%
10<7
# Out:
# False

# %%
# Less than

# %%
5 < 7
# Out:
# True

# %%
x = 10
y = 12

# %%
x>y
# Out:
# False

# %%
y>x
# Out:
# True

# %%
# Less than equal to

# %%
11<=12
# Out:
# True

# %%
x=12
y=12

# %%
x>y
# Out:
# False

# %%
y<=x
# Out:
# True

# %%
15 > y
# Out:
# True

# %%
14 < x
# Out:
# False

# %%
# Greater than or equal to

# %%
x >= y
# Out:
# True

# %%
y <= x
# Out:
# True

# %%
17 >= x
# Out:
# True

# %%
# Equal to

# %%
x ==y
# Out:
# True

# %%
x =13

# %%
x==y
# Out:
# False

# %%
x == 12
# Out:
# False

# %%
# Not Equal to

# %%
x != y
# Out:
# True

# %%
13 != 12
# Out:
# True

# %%
12.25 != 12
# Out:
# True
