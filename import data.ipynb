# %%
import pandas as pd
df = pd.read_csv("SFAReport.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8014 entries, 0 to 8013
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderID                8014 non-null   int64
#  1   BrandName              8014 non-null   object
#  2   EmployeeCode           8014 non-null   object
#  3   AgentName              8014 non-null   object
#  4   MnagerName             8014 non-null   object
#  5   Branch                 0 non-null      float64
#  6   Zone                   0 non-null      float64
#  7   Year                   8014 non-null   int64
#  8   Month                  8014 non-null   object
#  9   OrderDate              8014 non-null   object
#  10  OrderTime              8014 non-null   object
#  11  DeliveryDate           7381 non-null   object
#  12  DeliveryTime           7381 non-null   object
#  13  RecoDate               7380 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# OrderID                     0
# BrandName                   0
# EmployeeCode                0
# AgentName                   0
# MnagerName                  0
# Branch                   8014
# Zone                     8014
# Year                        0
# Month                       0
# OrderDate                   0
# OrderTime                   0
# DeliveryDate              633
# DeliveryTime              633
# RecoDate                  634
# RecoTime                  634
# OrderSyncdate               6
# OrderSyncTime               6
# Quantity                    0
# Unit                        0
# Value                       0
# OrderLatitude               0
# OrderLongitude              0
# OrderAddress              449
# CustomerCode                0
# CustomerName                0
# ContactNumber               0
# CustomerStatus              0
# CustomerType                0
# SalesType                   0
# Statename                  30
# CityName                  861
# ...
