# %% [markdown]
# # First Program

# %% [markdown]
# ## Markdown

# %%
print("This is my first program")
# Out:
# This is my first program

# %%
print("This is my second line....")
# Out:
# This is my second line....

# %%
print("Now l will learn python...")
# Out:
# Now l will learn python...

# %%
#The above statement are meant just for first program

# %%
#I have understood how to write a first program and how to document my code

# %%
# I have understood how to comment
# But now I am providing multiple lines.
# How will l comment now
